# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
data = pd.read_csv('housing.csv')
prices = data['MEDV']
features = data.drop('MEDV', axis = 1)

data.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
# TODO: Minimum price of the data
minimum_price = np.mean(prices)

# TODO: Maximum price of the data
maximum_price = np.max(prices)

# TODO: Mean price of the data
mean_price = np.mean(prices)

# TODO: Median price of the data
median_price = np.median(prices)

# TODO: Standard deviation of prices of the data
std_price = np.std(prices)

# Show the calculated statistics
print("Statistics for Boston housing dataset:\n")
print("Minimum price: ${:,.2f}".format(minimum_price))
print("Maximum price: ${:,.2f}".format(maximum_price))
print("Mean price: ${:,.2f}".format(mean_price))
print("Median price ${:,.2f}".format(median_price))
print("Standard deviation of prices: ${:,.2f}".format(std_price))
# Out:
# Statistics for Boston housing dataset:
#
# Minimum price: $454,342.94
# Maximum price: $1,024,800.00
# Mean price: $454,342.94
# Median price $438,900.00
# Standard deviation of prices: $165,171.13

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))

# %%
for i, col in enumerate(features.columns):
    # 3 plots here hence 1, 3
    plt.subplot(1, 3, i+1)
    x = data[col]
    y = prices
    plt.plot(x, y, 'o')
    # Create regression line
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('prices')

# %%
iris= pd.read_csv("iris.data")
iris.head()
# Out:
#     V1   V2   V3   V4        IRIS
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot 
import seaborn

fig, ax = pyplot.subplots(figsize =(9, 7)) 
sns.violinplot( ax = ax, y = iris["V1"] )
# Out:
# /home/ibab/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure()
fig,ax=plt.subplots(1,2,figsize=(17, 9))
iris.plot(x="V1",y="V2",kind="scatter",ax=ax[0],sharex=False,sharey=False,label="sepal",color='r')
iris.plot(x="V3",y="V4",kind="scatter",ax=ax[1],sharex=False,sharey=False,label="petal",color='b')
ax[0].set(title='V1 ', ylabel='sepal-width')
ax[1].set(title='V2',  ylabel='petal-width')
ax[0].legend()
ax[1].legend()
plt.show()
plt.close()

# %%
plt.figure()

fig,ax=plt.subplots(4,3,figsize=(17, 8))
iris["V1"].plot(kind="hist", ax=ax[0][0],label="setosa",color ='r',fontsize=10)
iris["V1"].plot(kind="hist", ax=ax[0][1],label="versicolor",color='b',fontsize=10)
iris["V1"].plot( kind="hist",ax=ax[0][2],label="virginica",color='g',fontsize=10)

iris["V2"].plot(kind="hist", ax=ax[1][0],label="setosa",color ='r',fontsize=10)
iris["V2"].plot(kind="hist", ax=ax[1][1],label="versicolor",color='b',fontsize=10)
iris["V2"].plot( kind="hist",ax=ax[1][2],label="virginica",color='g',fontsize=10)

iris["V3"].plot(kind="hist", ax=ax[2][0],label="setosa",color ='r',fontsize=10)
iris["V3"].plot(kind="hist", ax=ax[2][1],label="versicolor",color='b',fontsize=10)
iris["V3"].plot( kind="hist",ax=ax[2][2],label="virginica",color='g',fontsize=10)


iris["V4"].plot(kind="hist", ax=ax[3][0],label="setosa",color ='r',fontsize=10)
iris["V4"].plot(kind="hist", ax=ax[3][1],label="versicolor",color='b',fontsize=10)
iris["V4"].plot( kind="hist",ax=ax[3][2],label="virginica",color='g',fontsize=10)

plt.rcParams.update({'font.size': 10})
plt.tight_layout()
plt.show()
plt.close()

# %%
v1=iris['V1']
plt.boxplot(v1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc174587c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc174592320>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc174587828>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc1745929b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc174592cf8>],
#  'means': []}

# %%
v2= iris["V2"]
plt.scatter(v1, v2)

# %%
df= pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x= df["Insulin"]
y= df["BloodPressure"]
plt.scatter(x,y, marker='^')
plt.scatter(x, y, marker='o')

# %%
p= df["Glucose"]
#q= df["BMI"]
plt.stem(p)
# Out:
# <StemContainer object of 3 artists>

# %%
n_bins= 10
x = df["Insulin"]
y = df["BMI"]

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)
# Out:
# (array([ 11.,   0.,  15., 156., 268., 224.,  78.,  12.,   3.,   1.]),
#  array([ 0.  ,  6.71, 13.42, 20.13, 26.84, 33.55, 40.26, 46.97, 53.68,
#         60.39, 67.1 ]),
#  <a list of 10 Patch objects>)
# /home/ibab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(x, y)
# Out:
# /home/ibab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
import random
import numpy as np
radii = 10 * np.random.rand(20)
colors = plt.cm.viridis(radii / 10.)
width = (np.pi / 4) * np.random.rand(20)
ax = plt.subplot(111, projection='polar')
ax.bar(x, y, color=colors, alpha=0.5)
# Out:
# <BarContainer object of 768 artists>

# %%
import pandas as pd
wwine= pd.read_csv("winequality_white.csv")
wwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
import matplotlib.pyplot as plt
x= wwine["fixed acidity"]
y= wwine["volatile acidity"]
plt.hist(x)
# Out:
# (array([2.300e+01, 4.480e+02, 2.405e+03, 1.548e+03, 3.850e+02, 8.200e+01,
#         5.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 3.8 ,  4.84,  5.88,  6.92,  7.96,  9.  , 10.04, 11.08, 12.12,
#         13.16, 14.2 ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(x,y, marker= '^')
plt.scatter(x,y, marker= 'o')

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot 
import seaborn

fig, ax = pyplot.subplots(figsize =(9, 7)) 
sns.violinplot( ax = ax, y = wwine["residual sugar"] )
# Out:
# /home/ibab/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd2de044eb8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd2e1483b70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd2de0443c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd2d6878860>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd2d6878be0>],
#  'means': []}

# %%
plt.stem(y)
# Out:
# <StemContainer object of 3 artists>
